# %%
# %matplotlib inline
import pandas
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from pandas import DataFrame, Series
from ubxparser import UbxParser

# %%
parser = UbxParser("C:\\projects\\pixeltracker\\utils\\0.pubx")
parser.open()
parser.parse()

# %%
gps = DataFrame.from_dict(parser.GpsData)
acc = DataFrame.from_dict(parser.AccelerometerData)
sen = DataFrame.from_records(parser.SensorsData)
mic = DataFrame.from_dict(parser.MicrophoneData)

# %%
acc
# Out:
#              type      accx      accy       accz
# 0   accelerometer  2.106757 -0.421352   8.963295
# 1   accelerometer -0.153219  0.268133  11.414795
# 2   accelerometer  1.417273 -2.183367   8.388725
# 3   accelerometer  1.378969 -1.991844   8.733467
# 4   accelerometer -1.378969 -3.447421   9.384647
# 5   accelerometer -0.306437 -2.030149   7.469414
# 6   accelerometer -1.264054 -2.566414   9.078209
# 7   accelerometer -1.072531  2.643023  13.291725
# 8   accelerometer -0.995922 -0.995922   8.541943
# 9   accelerometer  0.383047 -0.804398   8.886684
# 10  accelerometer -0.421352  0.114914   9.729389
# 11  accelerometer -0.229828 -0.957617   9.537865
# 12  accelerometer -0.957617  0.076609   8.924992
# 13  accelerometer -1.034226  0.842703   9.729389
# 14  accelerometer -1.072531  2.259976   9.039906
# 15  accelerometer -1.072531  2.374890   9.806000
# 16  accelerometer -2.834546  1.953539  10.457176
# 17  accelerometer -3.026070 -0.153219  10.150742
# ...

# %%
ax = plt.gca()
acc.plot(kind='line',y='accx',ax=ax)
acc.plot(kind='line',y='accy', color='red', ax=ax)
plt.show()

# %%
#from pandas.plotting import scatter_matrix
#scatter_matrix(acc, alpha=0.2, figsize=(6, 6), diagonal='kde')
#acc.plot(kind='kde')
#df = sen
#plt.figure()
#bp = df.boxplot(by='X')

#mic.boxplot()
# plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='b', edgecolor='k')

#plt.legend(loc='best')
#mic.plot()
#sen.plot()
#acc.plot()
#gps.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-7a52c2f2db7d> in <module>
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(acc, alpha=0.2, figsize=(6, 6), diagonal='kde')
#       3 #acc.plot(kind='kde')
#       4 #df = sen
#       5 #plt.figure()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     126     """
#     127     plot_backend = _get_plot_backend("matplotlib")
# --> 128     return plot_backend.scatter_matrix(
#     129         frame=frame,
#     130         alpha=alpha,
#
# ...

# %%
from pandas.plotting import autocorrelation_plot
plt.figure()
data = Series(0.7 * rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))
autocorrelation_plot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f1d1d4d8ba8f> in <module>
#       1 from pandas.plotting import autocorrelation_plot
#       2 plt.figure()
# ----> 3 data = Series(0.7 * rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))
#       4 autocorrelation_plot(data)
#
# NameError: name 'rand' is not defined
